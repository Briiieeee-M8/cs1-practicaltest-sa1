# %% [markdown]
# <a href="https://colab.research.google.com/github/Briiieeee-M8/cs1q4practest/blob/main/cs1q4practest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# comsci1 q4 practest
# practical exam auuuuuh
# 1.Ask the user to enter their name 2.Ask the user to enter quiz scores 3.Repeatedly ask the user for multiple quiz scores
# 4.Calculate the total score 5.Compute the average score

# %%
print("Student score analyzer")

name = input("please enter your name")
qscore1 = int(input("Enter quiz score 1"))
qscore2 = int(input("Enter quiz score 2"))
qscore3 = int(input("Enter quiz score 3"))
total = int(qscore1 + qscore2 + qscore3)
average = int(total / 3)

def add(qscore1, qscore2, qscore3):
 total = int(qscore1 + qscore2 + qscore3)

print("calculating results...")

print("hello!", name)
print("your total average score is:", average)

if average >= 60:
  print("passing")
else:
 if average <=59:
  print("failing")

  print("Thank you for using student score analyzer")
# Out:
# Student score analyzer
# please enter your namebre
# Enter quiz score 14
# Enter quiz score 25
# Enter quiz score 36
# calculating results...
# hello! bre
# your total average score is: 5
# failing
